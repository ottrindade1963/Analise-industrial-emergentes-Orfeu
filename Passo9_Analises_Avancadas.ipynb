# %% [markdown]
# # Passo 9: Análises Avançadas, Robustez e Síntese Final
#
# Este notebook executa análises avançadas sobre os modelos treinados:
# - **Análise de Sensibilidade (What-If)**: Impacto de variações nas features chave
# - **Teste de Robustez**: Degradação do modelo com adição de ruído
# - **Visualizações Avançadas**: Gráficos de sensibilidade e robustez

# %%
# Clonar o repositório
# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu

# %%
# Instalar dependências
# !pip install pandas numpy scikit-learn xgboost matplotlib seaborn joblib scipy

# %%
# Importar e executar o pipeline
import sys
sys.path.append('/content/Analise-industrial-emergentes-Orfeu')

from passo9_advanced_pipeline import run_advanced_analysis_pipeline
run_advanced_analysis_pipeline()

# %%
# Visualizar resultados
import pandas as pd
from IPython.display import display

print('=== Análise de Sensibilidade ===')
df_sens = pd.read_csv('/content/Analise-industrial-emergentes-Orfeu/analises_avancadas/analise_sensibilidade.csv')
display(df_sens)

print('\n=== Teste de Robustez ===')
df_rob = pd.read_csv('/content/Analise-industrial-emergentes-Orfeu/analises_avancadas/teste_robustez.csv')
display(df_rob)

# %%
# Mostrar gráficos gerados
from IPython.display import Image, display
import glob

for img_path in sorted(glob.glob('/content/Analise-industrial-emergentes-Orfeu/analises_avancadas/visualizacoes_avancadas/*.png')):
    print(f'\n{img_path.split("/")[-1]}')
    display(Image(filename=img_path, width=800))
