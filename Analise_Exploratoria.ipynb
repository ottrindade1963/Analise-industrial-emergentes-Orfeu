# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/Analise-industrial-emergentes-Orfeu/blob/main/Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória — Países Emergentes
# Execute as 3 células abaixo em sequência (ou Runtime → Run all).

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas matplotlib seaborn openpyxl scipy

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
os.chdir(REPO)
sys.path.insert(0, os.getcwd())
print(f"\u2705 Diretório: {os.getcwd()}")
print(f"\u2705 Ficheiros .py: {[f for f in os.listdir('.') if f.endswith('.py')]}")
print(f"\u2705 Ficheiros .csv: {[f for f in os.listdir('.') if f.endswith('.csv')]}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 178 (delta 37), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (178/178), 2.52 MiB | 12.64 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# ✅ Diretório: /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
# ✅ Ficheiros .py: ['eda_loader.py', 'eda_config.py', 'extractor.py', 'eda_pipeline.py', 'eda_visualizacoes.py', 'config.py', 'pipeline.py']
# ✅ Ficheiros .csv: ['paises_emergentes.csv', 'wdi_emergentes_final.csv']

# %%
# 2. Executar análise exploratória completa
from eda_pipeline import executar_eda
executar_eda()
# Out:
# ============================================================
#   ANÁLISE EXPLORATÓRIA — PAÍSES EMERGENTES
# ============================================================
# ✅ Dados carregados: 3668 linhas x 11 colunas
#
# ============================================================
#   📋 RESUMO GERAL DO DATASET
# ============================================================
#   Período: 1996 – 2023
#   Países: 131
#   Registros: 3668
#
# ============================================================
#   🔍 VALORES AUSENTES
# ============================================================
# '                  Variável  Ausentes  % Ausentes  Válidos\n      PIB per capita (PPC)       203         5.5     3465\nForm. Bruta Capital (%PIB)       794        21.6     2874\n  Matrícula Secundário (%)      1373        37.4     2295\n           Comércio (%PIB)       639        17.4     3029\n                IDE (%PIB)       204         5.6     3464\n           População Total         0         0.0     3668\n     Emprego Indústria (%)       200         5.5     3468\nValor Agregado Ind. (%PIB)       275         7.5     3393'
# ============================================================
#   📊 ESTATÍSTICAS DESCRITIVAS COMPLETAS
# ============================================================
#                      Variável     N        Média     Mediana     Moda  \
# 0        PIB per capita (PPC)  3465      8630.65     6427.31   562.86
# 1  Form. Bruta Capital (%PIB)  2874        22.56       21.70    -2.42
# 2    Matrícula Secundário (%)  2295        67.09       73.57     3.35
# 3             Comércio (%PIB)  3029        73.72       68.63     0.03
# 4                  IDE (%PIB)  3464         3.88        2.44   -82.89
# 5             População Total  3668  43051229.31  9297515.00  9816.00
# 6       Emprego Indústria (%)  3468        17.52       17.52     1.67
# 7  Valor Agregado Ind. (%PIB)  3393        26.44       24.86     2.09
#
#    Desvio-Padrão     Variância   Mínimo    Q1 (25%)     Q3 (75%)  \
# 0   6.717940e+03  4.513075e+07   562.86     3227.12     12803.88
# 1   8.710000e+00  7.581000e+01    -2.42       17.15        26.84
# 2   2.704000e+01  7.310100e+02     3.35       44.29        88.57
# 3   3.503000e+01  1.226780e+03     0.03       47.01        94.18
# 4   6.870000e+00  4.726000e+01   -82.89        0.94         4.97
# 5   1.600165e+08  2.560528e+16  9342.00  2211589.75  27216174.25
# 6   7.600000e+00  5.775000e+01     1.67       11.68        23.04
# 7   1.188000e+01  1.411600e+02     2.09       18.42        32.34
#
#          Máximo          IQR     Amplitude  Assimetria  Curtose  CV (%)
# 0  3.999462e+04      9576.76  3.943176e+04        1.10     0.89    77.8
# 1  7.800000e+01         9.70  8.043000e+01        1.16     3.95    38.6
# 2  1.346700e+02        44.28  1.313200e+02       -0.39    -0.84    40.3
# 3  3.477200e+02        47.17  3.476900e+02        1.43     5.25    47.5
# 4  1.618200e+02         4.03  2.447200e+02        7.06   126.29   177.2
# 5  1.438070e+09  25004584.50  1.438060e+09        7.28    54.53   371.7
# 6  3.738000e+01        11.36  3.571000e+01        0.09    -0.62    43.4
# 7  8.667000e+01        13.92  8.458000e+01        1.24     2.81    44.9
# ============================================================
#   📐 INTERVALOS DE CONFIANÇA (95%) PARA A MÉDIA
# ============================================================
#                      Variável     N        Média  Erro Padrão  IC Inferior  \
# 0        PIB per capita (PPC)  3465      8630.65       114.13      8406.89
# 1  Form. Bruta Capital (%PIB)  2874        22.56         0.16        22.24
# 2    Matrícula Secundário (%)  2295        67.09         0.56        65.99
# 3             Comércio (%PIB)  3029        73.72         0.64        72.47
# 4                  IDE (%PIB)  3464         3.88         0.12         3.65
# 5             População Total  3668  43051229.31   2642105.40  37871088.08
# 6       Emprego Indústria (%)  3468        17.52         0.13        17.27
# 7  Valor Agregado Ind. (%PIB)  3393        26.44         0.20        26.04
#
#    IC Superior      Margem
# 0      8854.41      223.76
# 1        22.88        0.32
# 2        68.20        1.11
# 3        74.96        1.25
# 4         4.11        0.23
# 5  48231370.54  5180141.23
# 6        17.77        0.25
# 7        26.84        0.40
# ============================================================
#   🧪 TESTES DE NORMALIDADE
# ============================================================
#                      Variável  Shapiro-Wilk (stat) Shapiro-Wilk (p)  \
# 0        PIB per capita (PPC)               0.8938         8.48e-44
# 1  Form. Bruta Capital (%PIB)               0.9403         1.46e-32
# 2    Matrícula Secundário (%)               0.9595         8.27e-25
# 3             Comércio (%PIB)               0.9165         5.38e-38
# 4                  IDE (%PIB)               0.5185         8.69e-71
# 5             População Total               0.2315         6.92e-82
# 6       Emprego Indústria (%)               0.9880         1.46e-16
# 7  Valor Agregado Ind. (%PIB)               0.9306         4.27e-37
#
#   Normal (Shapiro)?  D'Agostino (stat) D'Agostino (p) Normal (D'Ag.)?
# 0               Não           533.9306      1.14e-116             Não
# 1               Não           691.3372      7.55e-151             Não
# 2               Não           287.6053       3.53e-63             Não
# 3               Não           949.6597      6.08e-207             Não
# 4               Não          4601.6739       0.00e+00             Não
# 5               Não          4680.7398       0.00e+00             Não
# 6               Não           125.9277       4.52e-28             Não
# 7               Não           779.0283      6.86e-170             Não
# ============================================================
#   📅 ESTATÍSTICAS POR DÉCADA
# ============================================================
#
#   ▸ PIB per capita (PPC):
#            N     Média  Mediana  Desvio-Padrão      Mín       Máx
# decada
# 1990s    487   6330.50  4766.11        4903.54   562.86  25585.51
# 2000s   1232   7654.53  5792.31        5980.42   702.85  39994.62
# 2010s   1247   9766.82  7930.09        7214.45   991.04  35711.49
# 2020s    499  10446.15  8594.39        7599.79  1030.77  35069.17
#   ▸ Form. Bruta Capital (%PIB):
#            N  Média  Mediana  Desvio-Padrão   Mín    Máx
# decada
# 1990s    368  20.32    19.67           8.20 -2.42  53.86
# 2000s   1004  22.00    20.84           8.66  1.10  68.93
# 2010s   1075  24.04    22.98           8.97  1.43  78.00
# 2020s    427  22.07    21.75           7.94  1.23  55.11
#   ▸ Matrícula Secundário (%):
#           N  Média  Mediana  Desvio-Padrão    Mín     Máx
# decada
# 1990s   231  50.31    54.27          24.94   5.04  101.60
# 2000s   883  60.85    67.33          27.17   5.94  117.80
# 2010s   856  73.03    80.17          24.92  10.80  127.19
# 2020s   325  80.36    87.68          22.54   3.35  134.67
#   ▸ Comércio (%PIB):
#            N  Média  Mediana  Desvio-Padrão    Mín     Máx
# decada
# 1990s    407  67.09    58.01          33.34   0.03  217.57
# 2000s   1067  74.33    69.51          33.65  20.29  220.41
# 2010s   1110  75.15    70.30          35.12  15.28  347.72
# 2020s    445  74.73    68.55          38.76   2.47  302.29
#   ▸ IDE (%PIB):
#            N  Média  Mediana  Desvio-Padrão    Mín     Máx
# decada
# 1990s    475   3.44     1.68          10.91 -82.89  161.82
# 2000s   1246   4.12     2.59           5.81 -10.26   64.38
# 2010s   1250   4.15     2.79           6.70 -37.17  103.34
# 2020s    493   3.02     2.09           4.17 -17.29   32.75
#   ▸ População Total:
#            N        Média     Mediana  Desvio-Padrão    Mín         Máx
# decada
# 1990s    524  35965566.31   7610361.5   1.400700e+08   9342  1252735000
# 2000s   1310  40070035.88   8495093.5   1.521739e+08   9544  1331260000
# 2010s   1310  46058639.86  10273631.5   1.678737e+08  10581  1407745000
# 2020s    524  50071349.54  11149915.0   1.768422e+08   9816  1438069596
#   ▸ Emprego Indústria (%):
#            N  Média  Mediana  Desvio-Padrão   Mín    Máx
# decada
# 1990s    496  17.07    17.23           8.08  1.79  37.28
# 2000s   1240  17.17    17.48           7.72  1.93  37.38
# 2010s   1240  17.80    17.47           7.33  1.69  36.65
# 2020s    492  18.14    17.89           7.40  1.67  35.00
#   ▸ Valor Agregado Ind. (%PIB):
#            N  Média  Mediana  Desvio-Padrão   Mín    Máx
# decada
# 1990s    440  25.84    24.98          10.50  6.98  79.57
# 2000s   1201  27.14    24.86          13.02  3.05  86.67
# 2010s   1258  26.21    24.87          11.48  4.82  78.06
# 2020s    494  25.86    24.74          11.06  2.09  78.90
# ============================================================
#   📊 GERANDO VISUALIZAÇÕES
# ============================================================
#
# 🔍 1. Mapa de valores ausentes...
#   💾 Salvo: resultados_eda/01_missing_heatmap.png
# 📊 2. Histogramas...
#   💾 Salvo: resultados_eda/02_histogramas.png
# 📦 3. Boxplots...
#   💾 Salvo: resultados_eda/03_boxplots.png
# 🔗 4. Matriz de correlação...
#   💾 Salvo: resultados_eda/04_correlacao.png
# 📈 5. Evolução temporal...
#   💾 Salvo: resultados_eda/05_evolucao_temporal.png
# 🏆 6. Top 10 países...
# /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/eda_visualizacoes.py:90: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, y="pais", x="pib_per_capita_ppc", ax=ax, palette="viridis")
#   💾 Salvo: resultados_eda/06_top10_pib.png
# 🔵 7. Scatter PIB vs Indústria...
#   💾 Salvo: resultados_eda/07_scatter_pib_industria.png
# 🎻 8. Violin plot emprego industrial...
# /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/eda_visualizacoes.py:120: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2, x="decada",
#   💾 Salvo: resultados_eda/08_violin_emprego.png
# 🔷 9. Pairplot...
#   💾 Salvo: resultados_eda/09_pairplot.png
# 🗺️ 10. Heatmap por país...
#   💾 Salvo: resultados_eda/10_heatmap_paises.png
#
# ============================================================
#   ✅ ANÁLISE CONCLUÍDA — Estatísticas + 10 gráficos!
#   📂 Gráficos em: resultados_eda/
# ============================================================

# %%
# 3. Ver todos os gráficos gerados
from IPython.display import Image, display
import os

for f in sorted(os.listdir("resultados_eda")):
    if f.endswith(".png"):
        print(f"\n{'='*50}\n  {f}\n{'='*50}")
        display(Image(f"resultados_eda/{f}", width=800))
# Out:
# ==================================================
#   01_missing_heatmap.png
# ==================================================
# ==================================================
#   02_histogramas.png
# ==================================================
# ==================================================
#   03_boxplots.png
# ==================================================
# ==================================================
#   04_correlacao.png
# ==================================================
# ==================================================
#   05_evolucao_temporal.png
# ==================================================
# ==================================================
#   06_top10_pib.png
# ==================================================
# ==================================================
#   07_scatter_pib_industria.png
# ==================================================
# ==================================================
#   08_violin_emprego.png
# ==================================================
# ==================================================
#   09_pairplot.png
# ==================================================
# ==================================================
#   10_heatmap_paises.png
# ==================================================
