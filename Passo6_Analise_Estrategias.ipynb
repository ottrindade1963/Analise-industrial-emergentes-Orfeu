# %% [markdown]
# # Passo 6: Análise das Estratégias de Agregação (H2)
#
# Este notebook executa o pipeline modularizado para analisar qual estratégia de inclusão de variáveis qualitativas (A1: Direta, A2: PCA, A3: Interação) produz o melhor resultado preditivo, testando a hipótese H2.

# %%
# 1. Clonar o repositório GitHub
# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu

# %%
# 2. Instalar dependências necessárias
# !pip install pandas numpy matplotlib seaborn

# %%
# 3. Executar o pipeline de Análise de Estratégias
# !python passo6_strategy_pipeline.py

# %%
# 4. Visualizar os resultados gerados
import os
import pandas as pd
from IPython.display import Image, display

out_dir = 'analise_estrategias'
viz_dir = os.path.join(out_dir, 'visualizacoes_estrategias')

if os.path.exists(os.path.join(out_dir, 'melhores_estrategias_resumo.csv')):
    print("\n--- Resumo das Melhores Estratégias ---")
    df = pd.read_csv(os.path.join(out_dir, 'melhores_estrategias_resumo.csv'))
    display(df)

if os.path.exists(viz_dir):
    for filename in os.listdir(viz_dir):
        if filename.endswith('.png'):
            print(f"\n--- {filename} ---")
            display(Image(filename=os.path.join(viz_dir, filename)))
else:
    print("Diretório de visualizações não encontrado.")
