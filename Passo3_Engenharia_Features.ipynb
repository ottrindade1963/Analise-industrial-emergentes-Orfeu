# %% [markdown]
# # Passo 3: Engenharia de Features e Estratégias de Inclusão Qualitativa
#
# Este notebook executa o pipeline modularizado para aplicar as 3 estratégias de agregação de variáveis qualitativas (A1: Inclusão Direta, A2: Fator Latente PCA, A3: Termos de Interação) aos datasets agregados (Inner, Left, Outer).

# %%
# 1. Clonar o repositório GitHub
# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu

# %%
# 2. Instalar dependências necessárias
# !pip install pandas numpy scikit-learn matplotlib seaborn

# %%
# 3. Executar o pipeline de Engenharia de Features
# !python passo3_feat_eng_pipeline.py

# %%
# 4. Visualizar os resultados gerados
import os
from IPython.display import Image, display

viz_dir = 'dados_engenharia/visualizacoes'
if os.path.exists(viz_dir):
    for filename in os.listdir(viz_dir):
        if filename.endswith('.png'):
            print(f"\n--- {filename} ---")
            display(Image(filename=os.path.join(viz_dir, filename)))
else:
    print("Diretório de visualizações não encontrado.")
