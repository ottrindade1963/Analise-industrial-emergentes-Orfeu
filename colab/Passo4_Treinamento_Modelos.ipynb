# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/Analise-industrial-emergentes-Orfeu/blob/main/colab/Passo4_Treinamento_Modelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Passo 4: Preparação Específica e Treinamento dos Modelos
#
# Este notebook executa o pipeline modularizado para treinar os modelos preditivos (Random Forest, XGBoost, SARIMAX) utilizando os datasets gerados no Passo 3 (Engenharia de Features).

# %%
# 1. Clonar o repositório GitHub
# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu
# Out:
# Cloning into 'Analise-industrial-emergentes-Orfeu'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 233 (delta 36), reused 2 (delta 2), pack-reused 170 (from 1)
# Receiving objects: 100% (233/233), 25.54 MiB | 18.42 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# /content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu

# %%
# 2. Instalar dependências necessárias
# !pip install pandas numpy scikit-learn xgboost statsmodels matplotlib seaborn joblib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.30.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (26.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# 3. Executar o pipeline de Treinamento de Modelos
# !python passo4_model_train_pipeline.py
# Out:
# ==================================================
# INICIANDO PIPELINE DE TREINAMENTO DE MODELOS (PASSO 4)
# ==================================================
#
# [1/2] Treinando Modelos...
#
# ========================================
# Treinando modelos para: nao_agregado - A1_Direta
# ========================================
#   -> Dados preparados (Divisão por Ano):
#      Treino (<= 2014): 2307 amostras
#      Validação (2015-2017): 373 amostras
#      Teste (> 2017): 740 amostras
#   -> Treinando Random Forest...
# Traceback (most recent call last):
#   File "/content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/passo4_model_train_pipeline.py", line 35, in <module>
#     run_model_training_pipeline()
#   File "/content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/passo4_model_train_pipeline.py", line 21, in run_model_training_pipeline
#     run_training_for_all()
#   File "/content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/passo4_model_train_processor.py", line 166, in run_training_for_all
#     trainer.train_all()
#   File "/content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/passo4_model_train_processor.py", line 134, in train_all
#     if 'RandomForest' in config.MODELS_TO_TRAIN: self.train_random_forest()
#                                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/passo4_model_train_processor.py", line 78, in train_random_forest
#     model.fit(self.X_train, self.y_train)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_forest.py", line 360, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py", line 1055, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py", line 839, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/generic.py", line 2153, in __array__
#     arr = np.asarray(values, dtype=dtype)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'AFG'

# %%
# 4. Visualizar os resultados gerados
import os
from IPython.display import Image, display

viz_dir = 'modelos_treinados/visualizacoes_treino'
if os.path.exists(viz_dir):
    for filename in os.listdir(viz_dir):
        if filename.endswith('.png'):
            print(f"\n--- {filename} ---")
            display(Image(filename=os.path.join(viz_dir, filename)))
else:
    print("Diretório de visualizações não encontrado.")
