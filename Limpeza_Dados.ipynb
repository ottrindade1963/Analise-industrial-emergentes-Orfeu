# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/Analise-industrial-emergentes-Orfeu/blob/main/Limpeza_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Limpeza e Tratamento de Dados
# Execute as 3 células abaixo em sequência (ou Runtime → Run all).

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
os.chdir(REPO)
sys.path.insert(0, os.getcwd())
print(f"✅ Diretório: {os.getcwd()}")
print(f"✅ Ficheiros .py: {[f for f in os.listdir('.') if f.endswith('.py')]}")
print(f"✅ Ficheiros .csv: {[f for f in os.listdir('.') if f.endswith('.csv')]}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 187 (delta 41), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (187/187), 2.53 MiB | 12.29 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# ✅ Diretório: /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
# ✅ Ficheiros .py: ['eda_loader.py', 'clean_pipeline.py', 'clean_processor.py', 'eda_config.py', 'extractor.py', 'eda_pipeline.py', 'clean_config.py', 'eda_visualizacoes.py', 'config.py', 'pipeline.py']
# ✅ Ficheiros .csv: ['paises_emergentes.csv', 'wdi_emergentes_final.csv']

# %%
# 2. Executar limpeza e tratamento
from clean_pipeline import executar_limpeza
df_limpo, stats = executar_limpeza()
# Out:
# ============================================================
#   LIMPEZA E TRATAMENTO DE DADOS
#   Países Emergentes — World Bank Indicators
# ============================================================
# ✅ Dados brutos carregados: 3668 linhas x 11 colunas
#
# 🔍 Fase 1: Remover países com >50% missing...
#   Removendo 4 país(es):
#     - Korea, Dem. People's Rep.: 74.6% missing
#     - Kosovo: 51.8% missing
#     - South Sudan: 61.6% missing
#     - Tuvalu: 50.9% missing
#   Resultado: 3556 linhas
#
# 🔍 Fase 2: Remover linhas com >40% missing...
#   Removidas 136 linhas
#   Resultado: 3420 linhas
#
# 🔍 Fase 3: Imputar valores ausentes...
#   PIB per capita (PPC): 95 → 95 missing
#   Form. Bruta Capital (%PIB): 570 → 543 missing
#   Matrícula Secundário (%): 1147 → 67 missing
#   Comércio (%PIB): 443 → 271 missing
#   IDE (%PIB): 74 → 34 missing
#   Emprego Indústria (%): 98 → 94 missing
#   Valor Agregado Ind. (%PIB): 119 → 100 missing
#
# 🔍 Fase 4: Validar ranges...
#   ✅ Todos os valores dentro dos ranges esperados
#
# ============================================================
#   📊 RELATÓRIO DE LIMPEZA
# ============================================================
#
#   Dados Originais:  3,668 linhas x 11 colunas
#   Dados Limpos:     3,420 linhas x 11 colunas
#   Linhas removidas: 248 (6.8%)
#
#   Países originais:  131
#   Países após limpeza: 127
#
#   Missing values (original):
#     PIB per capita (PPC): 203 (5.5%)
#     Form. Bruta Capital (%PIB): 794 (21.6%)
#     Matrícula Secundário (%): 1373 (37.4%)
#     Comércio (%PIB): 639 (17.4%)
#     IDE (%PIB): 204 (5.6%)
#     População Total: 0 (0.0%)
#     Emprego Indústria (%): 200 (5.5%)
#     Valor Agregado Ind. (%PIB): 275 (7.5%)
#
#   Missing values (limpo):
#     PIB per capita (PPC): 95 (2.8%)
#     Form. Bruta Capital (%PIB): 543 (15.9%)
#     Matrícula Secundário (%): 67 (2.0%)
#     Comércio (%PIB): 271 (7.9%)
#     IDE (%PIB): 34 (1.0%)
#     População Total: 0 (0.0%)
#     Emprego Indústria (%): 94 (2.7%)
#     Valor Agregado Ind. (%PIB): 100 (2.9%)
#
# 💾 Salvando dados limpos...
#   ✅ CSV: dados_limpos/wdi_emergentes_limpo.csv
#   ✅ XLSX: dados_limpos/wdi_emergentes_limpo.xlsx
#
# ============================================================
#   ✅ LIMPEZA CONCLUÍDA COM SUCESSO!
#   📁 Ficheiros gerados em: dados_limpos/
# ============================================================

# %%
# 3. Visualizar amostra dos dados limpos
print("\n📊 AMOSTRA DOS DADOS LIMPOS:")
print(f"\nShape: {df_limpo.shape}")
print(f"\nPrimeiras 5 linhas:")
display(df_limpo.head())
print(f"\nÚltimas 5 linhas:")
display(df_limpo.tail())
print(f"\nTipos de dados:")
print(df_limpo.dtypes)
print(f"\nEstatísticas descritivas:")
display(df_limpo.describe().round(2))
# Out:
# 📊 AMOSTRA DOS DADOS LIMPOS:
#
# Shape: (3420, 11)
#
# Primeiras 5 linhas:
#           pais codigo_iso3   ano  pib_per_capita_ppc  \
# 0  Afghanistan         AFG  2001         1454.110782
# 1  Afghanistan         AFG  2002         1774.308743
# 2  Afghanistan         AFG  2003         1815.928200
# 3  Afghanistan         AFG  2004         1776.918207
# 4  Afghanistan         AFG  2005         1908.114782
#
#    formacao_bruta_capital_fixo_percent_pib  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    matricula_ensino_secundario_percent  comercio_percent_pib  \
# 0                             14.04041             46.709895
# 1                             14.04041             46.709895
# 2                             13.95953             46.709895
# 3                             19.21438             46.709895
# 4                             20.27351             46.709895
#
#    investimento_estrangeiro_direto_percent_pib  populacao_total  \
# 0                                     0.024169         20284307
# 1                                     1.306950         21378117
# 2                                     1.278493         22733049
# 3                                     3.577104         23560654
# 4                                     4.368673         24404567
#
#    emprego_industria_percent_emprego_total  \
# 0                                12.638384
# 1                                12.961079
# 2                                13.175321
# 3                                13.185159
# 4                                13.500273
#
#    valor_agregado_industrial_percent_pib
# 0                              23.810127
# 1                              23.810127
# 2                              22.710864
# 3                              26.226790
# 4                              26.812099
# Últimas 5 linhas:
#           pais codigo_iso3   ano  pib_per_capita_ppc  \
# 3415  Zimbabwe         ZWE  2019         4993.843839
# 3416  Zimbabwe         ZWE  2020         4527.719881
# 3417  Zimbabwe         ZWE  2021         4827.088694
# 3418  Zimbabwe         ZWE  2022         5036.761361
# 3419  Zimbabwe         ZWE  2023         5218.022665
#
#       formacao_bruta_capital_fixo_percent_pib  \
# 3415                                 8.841332
# 3416                                 8.531115
# 3417                                10.764266
# 3418                                 9.602507
# 3419                                 9.675502
#
#       matricula_ensino_secundario_percent  comercio_percent_pib  \
# 3415                            52.415852             46.106544
# 3416                            52.415852             40.178406
# 3417                            52.415852             44.114559
# 3418                            52.415852             55.067352
# 3419                            52.415852             40.291261
#
#       investimento_estrangeiro_direto_percent_pib  populacao_total  \
# 3415                                     0.748473         15271368
# 3416                                     0.470482         15526888
# 3417                                     0.575185         15797210
# 3418                                     0.826254         16069056
# 3419                                     1.684321         16340822
#
#       emprego_industria_percent_emprego_total  \
# 3415                                11.195945
# 3416                                12.329262
# 3417                                13.487224
# 3418                                12.308347
# 3419                                11.392170
#
#       valor_agregado_industrial_percent_pib
# 3415                              38.974946
# 3416                              40.433645
# 3417                              36.916310
# 3418                              46.472364
# 3419                              33.255552
# Tipos de dados:
# pais                                            object
# codigo_iso3                                     object
# ano                                              int64
# pib_per_capita_ppc                             float64
# formacao_bruta_capital_fixo_percent_pib        float64
# matricula_ensino_secundario_percent            float64
# comercio_percent_pib                           float64
# investimento_estrangeiro_direto_percent_pib    float64
# populacao_total                                  int64
# emprego_industria_percent_emprego_total        float64
# valor_agregado_industrial_percent_pib          float64
# dtype: object
#
# Estatísticas descritivas:
#            ano  pib_per_capita_ppc  formacao_bruta_capital_fixo_percent_pib  \
# count  3420.00             3325.00                                  2877.00
# mean   2009.66             8735.25                                    22.59
# std       8.00             6752.88                                     8.72
# min    1996.00              562.86                                    -2.42
# 25%    2003.00             3214.25                                    17.17
# 50%    2010.00             6575.78                                    21.70
# 75%    2017.00            12961.03                                    26.82
# max    2023.00            39994.62                                    78.00
#
#        matricula_ensino_secundario_percent  comercio_percent_pib  \
# count                              3353.00               3149.00
# mean                                 63.29                 74.38
# std                                  27.87                 35.91
# min                                   3.35                  0.03
# 25%                                  40.02                 46.89
# 50%                                  68.19                 68.63
# 75%                                  86.72                 94.29
# max                                 134.67                347.72
#
#        investimento_estrangeiro_direto_percent_pib  populacao_total  \
# count                                      3386.00     3.420000e+03
# mean                                          3.80     4.567306e+07
# std                                           5.94     1.653889e+08
# min                                         -37.17     3.882700e+04
# 25%                                           0.97     2.677126e+06
# 50%                                           2.42     9.765072e+06
# 75%                                           4.87     2.852025e+07
# max                                         103.34     1.438070e+09
#
#        emprego_industria_percent_emprego_total  \
# count                                  3326.00
# mean                                     17.73
# std                                       7.47
# min                                       2.24
# 25%                                      11.97
# 50%                                      17.58
# 75%                                      23.10
# max                                      37.38
#
#        valor_agregado_industrial_percent_pib
# count                                3320.00
# mean                                   26.73
# std                                    11.79
# min                                     2.09
# 25%                                    18.88
# 50%                                    25.03
# 75%                                    32.49
# max                                    86.67
